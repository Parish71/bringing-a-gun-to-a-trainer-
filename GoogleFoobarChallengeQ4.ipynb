# %%
from math import atan2, pi, sqrt

def gcd(a, b):
    while b:
        a, b = b, a % b
    return a

def get_normalized_direction(dx, dy):
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

def calculate_reflections(x, y, dx, dy):
        reflections = set()
        while True:
            x += dx
            y += dy
            sq_distance = (x - x_you) ** 2 + (y - y_you) ** 2
            if sq_distance > max_sq_distance:
                break
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
        return reflections

for dx in range(-x_dim, x_dim + 1):
    for dy in range(-y_dim, y_dim + 1):
        if dx == 0 and dy == 0:
            continue
            reflections = calculate_reflections(x_trainer, y_trainer, dx, dy)
            if reflections:
                possible_directions |= reflections

return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5076\2453628572.py in <module>
#      28         return reflections
#      29
# ---> 30 for dx in range(-x_dim, x_dim + 1):
#      31     for dy in range(-y_dim, y_dim + 1):
#      32         if dx == 0 and dy == 0:
#
# NameError: name 'x_dim' is not defined

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x += dx
            y += dy
        return reflections

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx, dy)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5076\3548050778.py in <module>
#      32
#      33 # Test cases
# ---> 34 print(solution([3, 2], [1, 1], [2, 1], 4))
#      35 print(solution([300, 275], [150, 150], [185, 100], 500))
#      36
#
# ~\AppData\Local\Temp\ipykernel_5076\3548050778.py in solution(dimensions, your_position, trainer_position, distance)
#      25             if dx == 0 and dy == 0:
#      26                 continue
# ---> 27             reflections = calculate_reflections(dx, dy)
#      28             if reflections:
#      29                 possible_directions |= reflections
#
# ~\AppData\Local\Temp\ipykernel_5076\3548050778.py in calculate_reflections(dx, dy)
#      16         x, y = x_trainer + dx, y_trainer + dy
#      17         while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
# ...

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)


def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x += dx
            y += dy
        return reflections

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx, dy)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 27
# 324806

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)


def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x += dx
            y += dy
        return reflections

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx, dy)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 27
# 324806

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)


def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
            if dx > 0 and dy > 0:  # Consider reflections only in the first quadrant
                reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x += dx
            y += dy
        return reflections

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx, dy)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 4
# 85421

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)


def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()
    direction_dict = {}

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
            if dx > 0 and dy > 0:
                normalized_direction = get_normalized_direction(x - x_you, y - y_you)
                direction_dict[normalized_direction] = direction_dict.get(normalized_direction, 0) + 1
            x += dx
            y += dy

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            calculate_reflections(dx, dy)

    return len(direction_dict)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 4
# 85421

# %%
from math import gcd, sqrt


def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)


def solution(dimensions, your_position, trainer_position, distance):
    dim_x, dim_y = dimensions
    m_x, m_y = your_position

    # Function to get entity position in a room
    def get_entity_position_from_room_number(entity, room_number, dimensions):
        r_x, r_y = room_number
        e_x, e_y = entity
        dim_x, dim_y = dimensions

        res_x = dim_x * r_x + e_x if r_x % 2 == 0 else dim_x * r_x + (dim_x - e_x)
        res_y = dim_y * r_y + e_y if r_y % 2 == 0 else dim_y * r_y + (dim_y - e_y)

        return (res_x, res_y)

    # Calculate the number of rooms in different directions
    num_rooms_above_x_axis = (distance + m_y) // dim_y + 1
    num_rooms_below_x_axis = (distance - m_y) // dim_y + 1
    num_rooms_left_of_y_axis = (distance - m_x) // dim_x + 1
    num_rooms_right_of_y_axis = (distance + m_x) // dim_x + 1

    w = (num_rooms_right_of_y_axis + num_rooms_left_of_y_axis) * dim_x + 1
    h = (num_rooms_above_x_axis + num_rooms_below_x_axis) * dim_y + 1

    x_offset = num_rooms_left_of_y_axis * dim_x
    y_offset = num_rooms_below_x_axis * dim_y

    # Create a matrix representation of the space
    matrix = [[0 for _ in range(h)] for _ in range(w)]
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            tv_x, tv_y = get_entity_position_from_room_number(
                trainer_position, [i, j], dimensions)

            mv_x, mv_y = get_entity_position_from_room_number(
                your_position, [i, j], dimensions)

            matrix[tv_x + x_offset][tv_y + y_offset] = 1
            matrix[mv_x + x_offset][mv_y + y_offset] = 2

    # Calculate the number of hits
    hits = 0
    shots_taken = set()
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            t_x, t_y = get_entity_position_from_room_number(
                trainer_position, [i, j], dimensions)
            if distance < sqrt((t_x - m_x) ** 2 + (t_y - m_y) ** 2):
                continue
            delta_y = t_y - m_y
            delta_x = t_x - m_x
            d = gcd(delta_y, delta_x)
            delta_y //= d
            delta_x //= d
            if (delta_y, delta_x) in shots_taken:
                continue
            shots_taken.add((delta_y, delta_x))
            ray_x, ray_y = m_x + x_offset, m_y + y_offset
            while True:
                ray_x += delta_x
                ray_y += delta_y
                entity = matrix[ray_x][ray_y]
                if entity == 1:
                    hits += 1
                    break
                elif entity == 2:
                    break
    return hits


# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 7
# 9

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    room_width, room_height = dimensions
    your_x, your_y = your_position

    def get_entity_position_in_room(entity_position, room_number, dimensions):
        room_x, room_y = room_number
        entity_x, entity_y = entity_position
        room_width, room_height = dimensions

        pos_x = room_width * room_x + entity_x if room_x % 2 == 0 else room_width * room_x + (room_width - entity_x)
        pos_y = room_height * room_y + entity_y if room_y % 2 == 0 else room_height * room_y + (room_height - entity_y)

        return (pos_x, pos_y)

    num_rooms_above_x_axis = (distance + your_y) // room_height + 1
    num_rooms_below_x_axis = (distance - your_y) // room_height + 1
    num_rooms_left_of_y_axis = (distance - your_x) // room_width + 1
    num_rooms_right_of_y_axis = (distance + your_x) // room_width + 1

    total_width = (num_rooms_right_of_y_axis + num_rooms_left_of_y_axis) * room_width + 1
    total_height = (num_rooms_above_x_axis + num_rooms_below_x_axis) * room_height + 1

    x_offset = num_rooms_left_of_y_axis * room_width
    y_offset = num_rooms_below_x_axis * room_height

    matrix = [[0 for _ in range(total_height)] for _ in range(total_width)]
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            trainer_x, trainer_y = get_entity_position_in_room(trainer_position, [i, j], dimensions)
            your_x_in_room, your_y_in_room = get_entity_position_in_room(your_position, [i, j], dimensions)

            matrix[trainer_x + x_offset][trainer_y + y_offset] = 1
            matrix[your_x_in_room + x_offset][your_y_in_room + y_offset] = 2

    hits = 0
    shots_taken = set()
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            trainer_x, trainer_y = get_entity_position_in_room(trainer_position, [i, j], dimensions)
            if distance < sqrt((trainer_x - your_x) ** 2 + (trainer_y - your_y) ** 2):
                continue
            delta_y = trainer_y - your_y
            delta_x = trainer_x - your_x
            d = gcd(delta_y, delta_x)
            delta_y //= d
            delta_x //= d
            if (delta_y, delta_x) in shots_taken:
                continue
            shots_taken.add((delta_y, delta_x))
            ray_x, ray_y = your_x + x_offset, your_y + y_offset
            while True:
                ray_x += delta_x
                ray_y += delta_y
                entity = matrix[ray_x][ray_y]
                if entity == 1:
                    hits += 1
                    break
                elif entity == 2:
                    break
    return hits

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 7
# 9

# %%
from math import gcd, sqrt

# Function to get the normalized direction (in reduced form) of the ray.
def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

# Main function to solve the problem.
def count_unique_reflection_directions(dimensions, your_position, trainer_position, distance):
    room_width, room_height = dimensions
    your_x, your_y = your_position

    # Function to get the position of an entity within a room.
    def get_entity_position_in_room(entity_position, room_number, dimensions):
        room_x, room_y = room_number
        entity_x, entity_y = entity_position
        room_width, room_height = dimensions

        pos_x = room_width * room_x + entity_x if room_x % 2 == 0 else room_width * room_x + (room_width - entity_x)
        pos_y = room_height * room_y + entity_y if room_y % 2 == 0 else room_height * room_y + (room_height - entity_y)

        return (pos_x, pos_y)

    # Calculate the number of rooms in different directions.
    num_rooms_above_x_axis = (distance + your_y) // room_height + 1
    num_rooms_below_x_axis = (distance - your_y) // room_height + 1
    num_rooms_left_of_y_axis = (distance - your_x) // room_width + 1
    num_rooms_right_of_y_axis = (distance + your_x) // room_width + 1

    total_width = (num_rooms_right_of_y_axis + num_rooms_left_of_y_axis) * room_width + 1
    total_height = (num_rooms_above_x_axis + num_rooms_below_x_axis) * room_height + 1

    x_offset = num_rooms_left_of_y_axis * room_width
    y_offset = num_rooms_below_x_axis * room_height

    # Create a matrix representation of the space.
    matrix = [[0 for _ in range(total_height)] for _ in range(total_width)]
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            trainer_x, trainer_y = get_entity_position_in_room(trainer_position, [i, j], dimensions)
            your_x_in_room, your_y_in_room = get_entity_position_in_room(your_position, [i, j], dimensions)

            matrix[trainer_x + x_offset][trainer_y + y_offset] = 1
            matrix[your_x_in_room + x_offset][your_y_in_room + y_offset] = 2

    # Calculate the number of unique reflection directions resulting in a hit.
    hits = 0
    shots_taken = set()
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            trainer_x, trainer_y = get_entity_position_in_room(trainer_position, [i, j], dimensions)
            if distance < sqrt((trainer_x - your_x) ** 2 + (trainer_y - your_y) ** 2):
                continue
            delta_y = trainer_y - your_y
            delta_x = trainer_x - your_x
            d = gcd(delta_y, delta_x)
            delta_y //= d
            delta_x //= d
            if (delta_y, delta_x) in shots_taken:
                continue
            shots_taken.add((delta_y, delta_x))
            ray_x, ray_y = your_x + x_offset, your_y + y_offset
            while True:
                ray_x += delta_x
                ray_y += delta_y
                entity = matrix[ray_x][ray_y]
                if entity == 1:
                    hits += 1
                    break
                elif entity == 2:
                    break
    return hits

# Test cases
print(count_unique_reflection_directions([3, 2], [1, 1], [2, 1], 4))
print(count_unique_reflection_directions([300, 275], [150, 150], [185, 100], 500))

**best code until now**
# Out:
# 7
# 9

# %%
from math import gcd, sqrt

def get_normalized_direction(dx, dy):
    if dx == 0 and dy == 0:
        return (0, 0)
    
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    room_width, room_height = dimensions
    your_x, your_y = your_position

    def get_entity_position_in_room(entity_position, room_number, dimensions):
        room_x, room_y = room_number
        entity_x, entity_y = entity_position
        room_width, room_height = dimensions

        pos_x = room_width * room_x + entity_x if room_x % 2 == 0 else room_width * room_x + (room_width - entity_x)
        pos_y = room_height * room_y + entity_y if room_y % 2 == 0 else room_height * room_y + (room_height - entity_y)

        return (pos_x, pos_y)

    num_rooms_above_x_axis = (distance + your_y) // room_height + 1
    num_rooms_below_x_axis = (distance - your_y) // room_height + 1
    num_rooms_left_of_y_axis = (distance - your_x) // room_width + 1
    num_rooms_right_of_y_axis = (distance + your_x) // room_width + 1

    total_width = (num_rooms_right_of_y_axis + num_rooms_left_of_y_axis) * room_width + 1
    total_height = (num_rooms_above_x_axis + num_rooms_below_x_axis) * room_height + 1

    x_offset = num_rooms_left_of_y_axis * room_width
    y_offset = num_rooms_below_x_axis * room_height

    matrix = [[0 for _ in range(total_height)] for _ in range(total_width)]
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            trainer_x, trainer_y = get_entity_position_in_room(trainer_position, [i, j], dimensions)
            your_x_in_room, your_y_in_room = get_entity_position_in_room(your_position, [i, j], dimensions)

            matrix[trainer_x + x_offset][trainer_y + y_offset] = 1
            matrix[your_x_in_room + x_offset][your_y_in_room + y_offset] = 2

    hits = 0
    shots_taken = set()
    for i in range(-num_rooms_left_of_y_axis, num_rooms_right_of_y_axis):
        for j in range(-num_rooms_below_x_axis, num_rooms_above_x_axis):
            trainer_x, trainer_y = get_entity_position_in_room(trainer_position, [i, j], dimensions)
            if distance < sqrt((trainer_x - your_x) ** 2 + (trainer_y - your_y) ** 2):
                continue
            delta_y = trainer_y - your_y
            delta_x = trainer_x - your_x
            d = gcd(delta_y, delta_x)
            delta_y //= d
            delta_x //= d
            if (delta_y, delta_x) in shots_taken:
                continue
            shots_taken.add((delta_y, delta_x))
            ray_x, ray_y = your_x + x_offset, your_y + y_offset
            while True:
                ray_x += delta_x
                ray_y += delta_y
                entity = matrix[ray_x][ray_y]
                if entity == 1:
                    hits += 1
                    break
                elif entity == 2:
                    break
    return hits

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))
print(solution([300, 275], [150, 150], [185, 100], 500))
# Out:
# 7
# 9

# %%
from math import gcd

def get_normalized_direction(dx, dy):
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while x**2 + y**2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x, y = x + dx, y + dy
        return reflections

    for dx in range(1, distance // x_dim + 2):
        for dy in range(1, distance // y_dim + 2):
            if dx == 1 and dy == 1:
                continue
            reflections = calculate_reflections(dx * x_dim, dy * y_dim)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))  # Output: 7
print(solution([300, 275], [150, 150], [185, 100], 500))  # Output: 9
# Out:
# 0
# 0

# %%
from math import atan2, gcd

def get_normalized_direction(dx, dy):
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while (x - x_you) ** 2 + (y - y_you) ** 2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x, y = x + dx, y + dy
        return reflections

    for dx in range(-distance // x_dim, distance // x_dim + 1):
        for dy in range(-distance // y_dim, distance // y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx * x_dim, dy * y_dim)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))  # Output: 7
print(solution([300, 275], [150, 150], [185, 100], 500))  # Output: 9
# Out:
# 6
# 8

# %%
from math import atan2, pi

def get_normalized_direction(dx, dy):
    angle = atan2(dy, dx)
    return (dx, dy) if angle >= 0 else (-dx, -dy)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while x**2 + y**2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x, y = x + dx, y + dy
        return reflections

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx, dy)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))  # Output: 7
print(solution([300, 275], [150, 150], [185, 100], 500))  # Output: 9
# Out:
# 24
# 349821

# %%
from math import atan2, gcd

def get_normalized_direction(dx, dy):
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while x**2 + y**2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x, y = x + dx, y + dy
        return reflections

    for dx in range(-distance // x_dim - 1, distance // x_dim + 2):
        for dy in range(-distance // y_dim - 1, distance // y_dim + 2):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx * x_dim, dy * y_dim)
            if reflections:
                possible_directions |= reflections

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))  # Output: 7
print(solution([300, 275], [150, 150], [185, 100], 500))  # Output: 9
# Out:
# 7
# 10

# %%
from math import atan2, gcd

def get_normalized_direction(dx, dy):
    common_factor = gcd(abs(dx), abs(dy))
    return (dx // common_factor, dy // common_factor)

def solution(dimensions, your_position, trainer_position, distance):
    x_dim, y_dim = dimensions
    x_you, y_you = your_position
    x_trainer, y_trainer = trainer_position
    max_sq_distance = distance ** 2
    possible_directions = set()

    def calculate_reflections(dx, dy):
        reflections = set()
        x, y = x_trainer + dx, y_trainer + dy
        while x**2 + y**2 <= max_sq_distance:
            reflections.add(get_normalized_direction(x - x_you, y - y_you))
            x, y = x + dx, y + dy
        return reflections

    for dx in range(-distance // x_dim - 1, distance // x_dim + 2):
        for dy in range(-distance // y_dim - 1, distance // y_dim + 2):
            if dx == 0 and dy == 0:
                continue
            reflections = calculate_reflections(dx * x_dim, dy * y_dim)
            if reflections:
                possible_directions |= reflections
                # Add reflections in opposite directions
                possible_directions |= {(-dx, -dy) for dx, dy in reflections}

    return len(possible_directions)

# Test cases
print(solution([3, 2], [1, 1], [2, 1], 4))  # Output: 7
print(solution([300, 275], [150, 150], [185, 100], 500))  # Output: 9
# Out:
# 12
# 20

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 <= position[0] <= x and 0 <= position[1] <= y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    a, b = position
    x, y = dimension
    offset_x, offset_y = n * x, n * y
    positions = [
        (a - offset_x, b + offset_y),
        (a + offset_x, b + offset_y),
        (a - offset_x, b - offset_y),
        (a + offset_x, b - offset_y),
        (a - offset_x, b),
        (a, b + offset_y),
        (a + offset_x, b),
        (a, b - offset_y)
    ]
    return positions

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 0:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and get_root_bearing(your_position, position) not in unique_directions:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and get_root_bearing(your_position, position) not in unique_directions:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    dimensions = (3, 2)
    your_position = (1, 1)
    trainer_position = (2, 1)
    distance = 4

    print(count_unique_directions(dimensions, your_position, trainer_position, distance))  # Output should be 5
# Out:
# 12

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 <= position[0] <= x and 0 <= position[1] <= y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    a, b = position
    x, y = dimension
    offset_x, offset_y = n * x, n * y
    positions = [
        (a - offset_x, b + offset_y),
        (a + offset_x, b + offset_y),
        (a - offset_x, b - offset_y),
        (a + offset_x, b - offset_y),
        (a - offset_x, b),
        (a, b + offset_y),
        (a + offset_x, b),
        (a, b - offset_y)
    ]
    return positions

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 0:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and get_root_bearing(your_position, position) not in unique_directions:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and get_root_bearing(your_position, position) not in unique_directions:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 17
# 12

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 <= position[0] <= x and 0 <= position[1] <= y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    a, b = position
    x, y = dimension
    offset_x, offset_y = n * x, n * y
    positions = [
        (a - offset_x, b + offset_y),
        (a + offset_x, b + offset_y),
        (a - offset_x, b - offset_y),
        (a + offset_x, b - offset_y),
        (a - offset_x, b),
        (a, b + offset_y),
        (a + offset_x, b),
        (a, b - offset_y)
    ]
    return positions

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 0:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position and position != trainer_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 17
# 12

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 <= position[0] <= x and 0 <= position[1] <= y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y)
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b)
            ])
        n -= 1
    return res

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 0:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position and position != trainer_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 8
# 6

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y)
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b)
            ])
        n -= 1
    return res

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position and position != trainer_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 8
# 6

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y)
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b)
            ])
        n -= 1
    return res

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position and position != trainer_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 8
# 6

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y)
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b)
            ])
        n -= 1
    return res

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimension=dimensions, position=trainer_position, n=num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 8
# 6

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y),
                (-a, b + (n - 1) * y),  # Additional mirrored positions
                (a + (n - 1) * x, b),   # Additional mirrored positions
                (a + (n - 1) * x, -b),  # Additional mirrored positions
                (-a, -b - (n - 1) * y)  # Additional mirrored positions
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b),
                (-a, b + n * y),       # Additional mirrored positions
                (a + n * x, b),        # Additional mirrored positions
                (a - n * x, -b),       # Additional mirrored positions
                (a + n * x, -b)        # Additional mirrored positions
            ])
        n -= 1
    return res

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimension=dimensions, position=trainer_position, n=num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 11
# 8

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y)
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b)
            ])
        n -= 1
    return res

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(distance + 1):  # Modify to iterate up to 'distance'
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 8
# 6

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = []
    a, b = position
    x, y = dimension
    while n > 0:
        if n % 2 == 1:
            res.extend([
                (-a - (n - 1) * x, b),
                (a, (n + 1) * y - b),
                ((n + 1) * x - a, b),
                (a, -b - (n - 1) * y)
            ])
        if n % 2 == 0:
            res.extend([
                (a, (n + 1) * y + b),
                ((n + 1) * x + a, b),
                (a, b - n * y),
                (a - n * x, b)
            ])
        n -= 1
    return res

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimensions, trainer_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 8
# 6

# %%
import math

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = set()
    a, b = position
    x, y = dimension
    for i in range(n + 1):
        for j in range(n + 1):
            if i == 0 and j == 0:
                continue
            res.add((a + (2 * i - n) * x, b + (2 * j - n) * y))
    return list(res)

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimension=dimensions, position=trainer_position, n=num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 10
# 9

# %%
import math
import numpy as np

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not (0 < your_position[0] < dimensions[0]) or not (0 < your_position[1] < dimensions[1]):
        raise ValueError("Your position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    reflections = set()

    def find_reflections(start, end):
        rel_vector = np.array(end) - np.array(start)
        rel_distance = get_distance(start, end)
        n_reflections_x = math.ceil(distance / rel_distance)
        rel_vector_normalized = rel_vector / np.linalg.norm(rel_vector)

        for i in range(-n_reflections_x, n_reflections_x + 1):
            x_offset = i * rel_vector[0]
            y_offset = i * rel_vector[1]
            reflected_position = np.array(end) + np.array([x_offset, y_offset]) - 2 * (np.array([x_offset, y_offset]) @ rel_vector_normalized) * rel_vector_normalized
            reflected_position_distance = get_distance(your_position, reflected_position)
            if reflected_position_distance <= distance:
                reflections.add(get_root_bearing(your_position, reflected_position))

    find_reflections(your_position, trainer_position)
    find_reflections(trainer_position, your_position)

    return len(reflections)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 4
# 2

# %%
import numpy as np

def solution(dimensions, your_position, trainer_position, distance):
    # Convert dimensions, positions, and distance to NumPy arrays for vector operations
    dimensions = np.array(dimensions)
    your_position = np.array(your_position)
    trainer_position = np.array(trainer_position)

    if np.linalg.norm(your_position - trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = (distance // dimensions) + 1

    for num in range(max_room + 1):
        for i in range(2):
            for j in range(2):
                if i == 0 and j == 0:
                    continue
                mirrored_trainer = trainer_position + [i * dimensions[0] * (2 * num - 1), j * dimensions[1] * (2 * num - 1)]
                direction = np.arctan2(mirrored_trainer[1] - your_position[1], mirrored_trainer[0] - your_position[0])
                if np.linalg.norm(mirrored_trainer - your_position) <= distance:
                    unique_directions.add(direction)

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5076\3332293832.py in <module>
#      27 # Test cases
#      28 if __name__ == "__main__":
# ---> 29     print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
#      30     print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
#
# ~\AppData\Local\Temp\ipykernel_5076\3332293832.py in solution(dimensions, your_position, trainer_position, distance)
#      13     max_room = (distance // dimensions) + 1
#      14
# ---> 15     for num in range(max_room + 1):
#      16         for i in range(2):
#      17             for j in range(2):
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
import math
import numpy as np

def get_distance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def get_root_bearing(start, end):
    return math.atan2(end[1] - start[1], end[0] - start[0])

def is_within_distance(your_position, position, distance):
    return get_distance(your_position, position) <= distance

def is_within_bounds(position, dimension):
    x, y = dimension
    return 0 < position[0] < x and 0 < position[1] < y

def find_max_room(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    rooms_above_x = (distance + b) // y + 1
    rooms_right_y = (distance + a) // x + 1
    return max(rooms_right_y, rooms_above_x)

def get_positions(dimension, position, n):
    res = set()
    a, b = position
    x, y = dimension
    mirror_matrix = np.array([[1, 0], [0, 1], [-1, 0], [0, -1]])
    for i in range(n + 1):
        for j in range(n + 1):
            if i == 0 and j == 0:
                continue
            vec = np.array([a, b])
            mirror_pos = vec + (2 * i - n) * x * mirror_matrix + (2 * j - n) * y * mirror_matrix
            res.add(tuple(mirror_pos[0]))
    return list(res)

def solution(dimensions, your_position, trainer_position, distance):
    if not dimensions or len(dimensions) != 2 or distance < 1:
        raise ValueError("Invalid dimensions or distance.")

    if not is_within_bounds(your_position, dimensions) or not is_within_bounds(trainer_position, dimensions):
        raise ValueError("Your position or trainer's position is out of bounds.")

    if get_distance(your_position, trainer_position) > distance:
        return 0

    unique_directions = set()
    max_room = find_max_room(dimensions, distance, your_position)

    for num in range(max_room + 1):
        for position in get_positions(dimensions, your_position, num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

        for position in get_positions(dimension=dimensions, position=trainer_position, n=num):
            if is_within_distance(your_position, position, distance) and position != your_position:
                unique_directions.add(get_root_bearing(your_position, position))

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 10
# 2

# %%
import math

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    def simulate_bouncing_ball(initial_x, initial_y, initial_speed_x, initial_speed_y, gravity, bounce_factor, time_steps):
        positions = set()
        x = initial_x
        y = initial_y
        speed_x = initial_speed_x
        speed_y = initial_speed_y

        for _ in range(time_steps):
            speed_y += gravity
            x += speed_x
            y += speed_y

            if x < 0:
                x = -x
                speed_x = -speed_x * bounce_factor

            if y < 0:
                y = -y
                speed_y = -speed_y * bounce_factor

            positions.add((round(x), round(y)))  # Round positions to integers

        return positions

    x_dim, y_dim = dimensions
    max_time_steps = math.ceil(distance / math.sqrt(x_dim**2 + y_dim**2))
    
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position
    
    your_positions = simulate_bouncing_ball(your_x, your_y, 1, 0, 0.5, 0.8, max_time_steps)
    trainer_positions = simulate_bouncing_ball(trainer_x, trainer_y, 1, 0, 0.5, 0.8, max_time_steps)

    unique_directions = set()

    for your_pos in your_positions:
        for trainer_pos in trainer_positions:
            dx = trainer_pos[0] - your_pos[0]
            dy = trainer_pos[1] - your_pos[1]

            gcd = math.gcd(dx, dy)

            # Skip adding the direction if the GCD is 0 (positions are the same)
            if gcd == 0:
                continue

            normalized_direction = (dx // gcd, dy // gcd)
            unique_directions.add(normalized_direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 3
# 1

# %%
import math

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    def simulate_bouncing_ball(initial_x, initial_y, initial_speed_x, initial_speed_y, gravity, bounce_factor, time_steps):
        positions = set()
        x = initial_x
        y = initial_y
        speed_x = initial_speed_x
        speed_y = initial_speed_y

        for _ in range(time_steps):
            speed_y += gravity
            x += speed_x
            y += speed_y

            if x < 0:
                x = -x
                speed_x = -speed_x * bounce_factor

            if y < 0:
                y = -y
                speed_y = -speed_y * bounce_factor

            positions.add((round(x), round(y)))  # Round positions to integers

        return positions

    x_dim, y_dim = dimensions
    max_time_steps = math.ceil(distance / math.sqrt(x_dim**2 + y_dim**2))
    
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position
    
    your_positions = simulate_bouncing_ball(your_x, your_y, 1, 0, 0.5, 0.8, max_time_steps)
    trainer_positions = simulate_bouncing_ball(trainer_x, trainer_y, 1, 0, 0.5, 0.8, max_time_steps)

    unique_directions = set()

    for your_pos in your_positions:
        for trainer_pos in trainer_positions:
            dx = trainer_pos[0] - your_pos[0]
            dy = trainer_pos[1] - your_pos[1]

            gcd = math.gcd(dx, dy) if dx != 0 or dy != 0 else 1
            normalized_direction = (dx // gcd, dy // gcd)
            unique_directions.add(normalized_direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 3
# 2

# %%
import math

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    def simulate_bouncing_ball(initial_x, initial_y, initial_speed_x, initial_speed_y, gravity, bounce_factor, time_steps):
        positions = set()
        x = initial_x
        y = initial_y
        speed_x = initial_speed_x
        speed_y = initial_speed_y

        for _ in range(time_steps):
            speed_y += gravity
            x += speed_x
            y += speed_y

            if x < 0:
                x = -x
                speed_x = -speed_x * bounce_factor

            if y < 0:
                y = -y
                speed_y = -speed_y * bounce_factor

            positions.add((round(x), round(y)))  # Round positions to integers

        return positions

    x_dim, y_dim = dimensions
    max_time_steps = math.ceil(distance / math.sqrt(x_dim**2 + y_dim**2))
    
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position
    
    your_positions = simulate_bouncing_ball(your_x, your_y, 1, 0, 0.5, 0.8, max_time_steps)
    trainer_positions = simulate_bouncing_ball(trainer_x, trainer_y, 1, 0, 0.5, 0.8, max_time_steps)

    unique_directions = set()

    for your_pos in your_positions:
        for trainer_pos in trainer_positions:
            dx = trainer_pos[0] - your_pos[0]
            dy = trainer_pos[1] - your_pos[1]

            gcd = math.gcd(dx, dy)
            if gcd == 0:
                # Handle the case when the positions are the same or align horizontally/vertically
                normalized_direction = (dx, dy)
            else:
                normalized_direction = (dx // gcd, dy // gcd)
            unique_directions.add(normalized_direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 3
# 2

# %%
import math

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    def get_normalized_direction(position1, position2):
        dx = position2[0] - position1[0]
        dy = position2[1] - position1[1]
        gcd = math.gcd(dx, dy)
        if gcd == 0:
            return (dx, dy)
        return (dx // gcd, dy // gcd)

    x_dim, y_dim = dimensions
    max_time_steps = math.ceil(distance / math.sqrt(x_dim**2 + y_dim**2))
    
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position
    
    unique_directions = set()

    for dx in range(-max_time_steps, max_time_steps + 1):
        for dy in range(-max_time_steps, max_time_steps + 1):
            if dx == 0 and dy == 0:
                continue
            
            for multiplier in range(1, max_time_steps + 1):
                x = trainer_x + dx * x_dim * multiplier
                y = trainer_y + dy * y_dim * multiplier

                if abs(x - your_x) <= distance and abs(y - your_y) <= distance:
                    normalized_direction = get_normalized_direction(your_position, (x, y))
                    unique_directions.add(normalized_direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 11
# 14

# %%
import math

def count_unique_directions(dimensions, your_position, trainer_position, distance):
    def get_normalized_direction(position1, position2):
        # Calculate the direction vector between two positions and normalize it.
        dx = position2[0] - position1[0]
        dy = position2[1] - position1[1]
        gcd = math.gcd(dx, dy)
        if gcd == 0:
            return (dx, dy)
        return (dx // gcd, dy // gcd)

    x_dim, y_dim = dimensions
    max_time_steps = math.ceil(distance / math.sqrt(x_dim**2 + y_dim**2))
    
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position
    
    unique_directions = set()

    for dx in range(-max_time_steps, max_time_steps + 1):
        for dy in range(-max_time_steps, max_time_steps + 1):
            if dx == 0 and dy == 0:
                continue
            
            for multiplier in range(1, max_time_steps + 1):
                # Calculate the positions of the trainer based on dx, dy, and multiplier.
                x = trainer_x + dx * x_dim * multiplier
                y = trainer_y + dy * y_dim * multiplier

                # Check if the trainer's position is within the shooting distance.
                if abs(x - your_x) <= distance and abs(y - your_y) <= distance:
                    # Get the normalized direction vector between your position and the trainer's position.
                    normalized_direction = get_normalized_direction(your_position, (x, y))
                    unique_directions.add(normalized_direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(count_unique_directions([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(count_unique_directions([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 11
# 14

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    def get_reflection_candidates(position, dimension):
        x, y = dimension
        px, py = position
        reflections = set()
        for dx in [-1, 1]:
            for dy in [-1, 1]:
                x_reflection = (dx * (2 * x - px)) % (2 * x)
                y_reflection = (dy * (2 * y - py)) % (2 * y)
                reflections.add((x_reflection, y_reflection))
        return reflections

    x_dim, y_dim = dimensions
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position

    reflections_your_pos = get_reflection_candidates(your_position, dimensions)
    reflections_trainer_pos = get_reflection_candidates(trainer_position, dimensions)

    unique_directions = set()

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            for reflections_x in [0, x_dim]:
                for reflections_y in [0, y_dim]:
                    new_x = trainer_x + dx + reflections_x
                    new_y = trainer_y + dy + reflections_y
                    dist_sq = (new_x - your_x) ** 2 + (new_y - your_y) ** 2
                    if dist_sq <= distance ** 2:
                        direction = (dx, dy)
                        unique_directions.add(direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 331151
# 32

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    def get_reflection_candidates(position, dimension):
        x, y = dimension
        px, py = position
        reflections = set()
        for dx in [-1, 1]:
            for dy in [-1, 1]:
                x_reflection = (dx * (2 * x - px)) % (2 * x)
                y_reflection = (dy * (2 * y - py)) % (2 * y)
                reflections.add((x_reflection, y_reflection))
        return reflections

    x_dim, y_dim = dimensions
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position

    reflections_your_pos = get_reflection_candidates(your_position, dimensions)
    reflections_trainer_pos = get_reflection_candidates(trainer_position, dimensions)

    unique_directions = set()

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            for reflections_x in [0, x_dim]:
                for reflections_y in [0, y_dim]:
                    new_x = trainer_x + dx + reflections_x
                    new_y = trainer_y + dy + reflections_y
                    dist_sq = (new_x - your_x) ** 2 + (new_y - your_y) ** 2
                    if dist_sq <= distance ** 2:
                        direction = (dx, dy)
                        unique_directions.add(direction)

    return len(unique_directions)


# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 331151
# 32

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    # Your code here
    if getDistance(your_position, trainer_position) > distance:
        return 0
    res = {getRootBearing(your_position, trainer_position): getDistance(your_position, trainer_position)}
    maxRoom = findMaxRoom(dimensions, distance, your_position)
    set = {}
    # check if the position in the same direction as your_position mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, your_position, num):
            if checkPoint(your_position, position, dimensions) and getDistance(your_position, position) < distance and getRootBearing(your_position, position) not in set:
                set[getRootBearing(your_position, position)] = getDistance(your_position, position)
            else:
                continue
    #check every position of mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, trainer_position, num):
            if checkPoint(your_position, position, dimensions) and getRootBearing(your_position, position) not in res and getDistance(your_position, position) <= distance and getRootBearing(your_position, position) not in set:
                res[getRootBearing(your_position, position)] = getDistance(your_position, position)
            elif getRootBearing(your_position, position) in set:
                if set[getRootBearing(your_position, position)] > getDistance(your_position, position):
                    res[getRootBearing(your_position, position)] = getDistance(your_position, position)
                else:
                    continue
            else:
                continue
    return len(res)

def checkPoint(your_position, position, dimension):  # check not hitting corner or vertically horizonally hitting
    x, y = dimension
    a1, b1 = position
    leftUp = getRootBearing(your_position, [0, y])
    rightDown = getRootBearing(your_position, [x, 0])
    leftDown = getRootBearing(your_position, [0, 0])
    rightUp = getRootBearing(your_position, [x, y])
    if position[0] != your_position[0] and position[1] != your_position[1]:
        if a1 < 0 and b1 > 0 and getRootBearing(your_position, position) != leftUp:
            return True
        elif a1 > 0 and b1 > 0 and getRootBearing(your_position, position) != rightUp:
            return True
        elif a1 < 0 and b1 < 0 and getRootBearing(your_position, position) != leftDown:
            return True
        elif a1 > 0 and b1 < 0 and getRootBearing(your_position, position) != rightDown:
            return True
        else:
            return False
    else:
        return False

def getDistance(position1, position2):
    return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

def getRootBearing(start, end):
    #get the direction
    return math.atan2(end[1] - start[1], end[0] - start[0])

def findMaxRoom(dimension, distance, your_position):
    a, b = your_position
    x, y = dimension
    roomsAboveX = (distance + b) // y + 1
    roomsRightY = (distance + a) // x + 1
    return max(roomsRightY, roomsAboveX)

def getPosition(dimension, trainer_position, n):
    res = []
    a, b = trainer_position
    x, y = dimension
    if n % 2 == 0:
        res.extend([(-a - n * x, (n + 2) * y - b), ((n + 2) * x - a, (n + 2) * y - b), (-a - n * x, -b - n * y), ((n + 2) * x - a, -b - n * y), ((-a - n * x), b), (a, (n + 2) * y - b), ((n + 2) * x - a, b), (a, -b - n * y)])
    else:
        res.extend(
            [(a - (n + 1) * x, (n + 1) * y + b), ((n + 1) * x + a, (n + 1) * y + b), (a - (n + 1) * x, b - (n + 1) * y), ((n + 1) * x + a, b - (n + 1) * y), (a - (n + 1) * x, b), (a, (n + 1) * y + b), ((n + 1) * x + a, b), (a, b - (n + 1) * y)])
    while n > 0:
        if n % 2 == 1:
            res.extend(
                [(-a - (n - 1) * x, res[0][1]), (res[0][0], (n + 1) * y - b), ((n + 1) * x - a, res[1][1]), (res[1][0], (n + 1) * y - b), (res[2][0], -b - (n - 1) * y), (-a - (n - 1) * x, res[2][1]), ((n + 1) * x - a, res[3][1]), (res[3][0], -b - (n - 1) * y)])
                 # 0.right                      # 0.down                      # 1.left                      # 1.down                      # 2.up                        # 2.right                       # 3.left                      # 3.up
        if n % 2 == 0:
            res.extend([(a - n * x, res[0][1]), (res[0][0], n * y + b), (n * x + a, res[1][1]), (res[1][0], n * y + b), (res[2][0], b - n * y), (a - n * x, res[2][1]), (n * x + a, res[3][1]), (res[3][0], b - n * y)])
                        # 0.right                # 0.down                # 1.left                # 1.down               # 2.up                  # 2.right                 # 3.left                 # 3.up
        n -= 1
    return res

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    def get_reflection_candidates(position, dimension):
        x, y = dimension
        px, py = position
        reflections = set()
        for dx in [-1, 1]:
            for dy in [-1, 1]:
                x_reflection = (dx * (2 * x - px)) % (2 * x)
                y_reflection = (dy * (2 * y - py)) % (2 * y)
                reflections.add((x_reflection, y_reflection))
        return reflections

    x_dim, y_dim = dimensions
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position

    reflections_your_pos = get_reflection_candidates(your_position, dimensions)
    reflections_trainer_pos = get_reflection_candidates(trainer_position, dimensions)

    unique_directions = set()

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            for reflections_x in [0, x_dim]:
                for reflections_y in [0, y_dim]:
                    new_x = trainer_x + dx + reflections_x
                    new_y = trainer_y + dy + reflections_y
                    dist_sq = (new_x - your_x) ** 2 + (new_y - your_y) ** 2
                    if dist_sq <= distance ** 2:
                        direction = (dx, dy)
                        unique_directions.add(direction)

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 331151
# 32

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    def get_distance(position1, position2):
        return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

    def get_reflection_candidates(position, dimension):
        x, y = dimension
        px, py = position
        reflections = set()
        for dx in [-1, 1]:
            for dy in [-1, 1]:
                x_reflection = (dx * (2 * x - px)) % (2 * x)
                y_reflection = (dy * (2 * y - py)) % (2 * y)
                reflections.add((x_reflection, y_reflection))
        return reflections

    x_dim, y_dim = dimensions
    your_x, your_y = your_position
    trainer_x, trainer_y = trainer_position

    reflections_your_pos = get_reflection_candidates(your_position, dimensions)
    reflections_trainer_pos = get_reflection_candidates(trainer_position, dimensions)

    unique_directions = set()

    for dx in range(-x_dim, x_dim + 1):
        for dy in range(-y_dim, y_dim + 1):
            for reflections_x in reflections_your_pos:
                for reflections_y in reflections_trainer_pos:
                    new_x = trainer_x + dx + reflections_x[0]
                    new_y = trainer_y + dy + reflections_y[1]
                    dist_sq = (new_x - your_x) ** 2 + (new_y - your_y) ** 2
                    if dist_sq <= distance ** 2:
                        direction = (dx, dy)
                        unique_directions.add(direction)

    return len(unique_directions)

# Test cases
if __name__ == "__main__":
    print(solution([300, 275], [150, 150], [185, 100], 500))  # Output should be 9
    print(solution([3, 2], [1, 1], [2, 1], 4))  # Output should be 7
# Out:
# 321463
# 25

# %% [markdown]
# ## MVP.0.0.2

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    def getDistance(position1, position2):
        return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

    def getRootBearing(start, end):
        return math.atan2(end[1] - start[1], end[0] - start[0])

    def findMaxRoom(dimension, distance, your_position):
        a, b = your_position
        x, y = dimension
        roomsAboveX = (distance + b) // y + 1
        roomsRightY = (distance + a) // x + 1
        return max(roomsRightY, roomsAboveX)

    def getPosition(dimension, trainer_position, n):
        res = []
        a, b = trainer_position
        x, y = dimension
        if n % 2 == 0:
            res.extend([(-a - n * x, (n + 2) * y - b), ((n + 2) * x - a, (n + 2) * y - b), (-a - n * x, -b - n * y), ((n + 2) * x - a, -b - n * y), ((-a - n * x), b), (a, (n + 2) * y - b), ((n + 2) * x - a, b), (a, -b - n * y)])
        else:
            res.extend(
                [(a - (n + 1) * x, (n + 1) * y + b), ((n + 1) * x + a, (n + 1) * y + b), (a - (n + 1) * x, b - (n + 1) * y), ((n + 1) * x + a, b - (n + 1) * y), (a - (n + 1) * x, b), (a, (n + 1) * y + b), ((n + 1) * x + a, b), (a, b - (n + 1) * y)])
        while n > 0:
            if n % 2 == 1:
                res.extend(
                    [(-a - (n - 1) * x, res[0][1]), (res[0][0], (n + 1) * y - b), ((n + 1) * x - a, res[1][1]), (res[1][0], (n + 1) * y - b), (res[2][0], -b - (n - 1) * y), (-a - (n - 1) * x, res[2][1]), ((n + 1) * x - a, res[3][1]), (res[3][0], -b - (n - 1) * y)])
            else:
                res.extend([(a - n * x, res[0][1]), (res[0][0], n * y + b), (n * x + a, res[1][1]), (res[1][0], n * y + b), (res[2][0], b - n * y), (a - n * x, res[2][1]), (n * x + a, res[3][1]), (res[3][0], b - n * y)])
            n -= 1
        return res

    def checkPoint(your_position, position, dimension):
        x, y = dimension
        a1, b1 = position
        leftUp = getRootBearing(your_position, [0, y])
        rightDown = getRootBearing(your_position, [x, 0])
        leftDown = getRootBearing(your_position, [0, 0])
        rightUp = getRootBearing(your_position, [x, y])
        if position[0] != your_position[0] and position[1] != your_position[1]:
            if a1 < 0 and b1 > 0 and getRootBearing(your_position, position) != leftUp:
                return True
            elif a1 > 0 and b1 > 0 and getRootBearing(your_position, position) != rightUp:
                return True
            elif a1 < 0 and b1 < 0 and getRootBearing(your_position, position) != leftDown:
                return True
            elif a1 > 0 and b1 < 0 and getRootBearing(your_position, position) != rightDown:
                return True
            else:
                return False
        else:
            return False

    if getDistance(your_position, trainer_position) > distance:
        return 0

    res = {getRootBearing(your_position, trainer_position): getDistance(your_position, trainer_position)}
    maxRoom = findMaxRoom(dimensions, distance, your_position)
    unique_directions = set()

    # check if the position is in the same direction as your_position mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, your_position, num):
            if checkPoint(your_position, position, dimensions) and getDistance(your_position, position) < distance and getRootBearing(your_position, position) not in unique_directions:
                unique_directions.add(getRootBearing(your_position, position))

    # check every position of mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, trainer_position, num):
            if checkPoint(your_position, position, dimensions) and getRootBearing(your_position, position) not in res and getDistance(your_position, position) <= distance and getRootBearing(your_position, position) not in unique_directions:
                res[getRootBearing(your_position, position)] = getDistance(your_position, position)
            elif getRootBearing(your_position, position) in unique_directions:
                if unique_directions[getRootBearing(your_position, position)] > getDistance(your_position, position):
                    res[getRootBearing(your_position, position)] = getDistance(your_position, position)

    return len(res)

# %% [markdown]
# ## Test Cases:

# %%
# Test case with a small room, your_position and trainer_position on the same axis,
# and distance that hits the trainer without bouncing.
print(solution([2, 2], [0, 1], [0, 0], 2))  # Output should be 1

# Test case with a small room, your_position and trainer_position on the same axis,
# and distance that hits the trainer with bouncing.
print(solution([2, 2], [0, 1], [0, 0], 3))  # Output should be 1

# Test case with a small room, your_position and trainer_position on the same axis,
# and distance that doesn't hit the trainer.
print(solution([2, 2], [0, 1], [0, 0], 1))  # Output should be 0

# Test case with your_position and trainer_position in opposite corners of a room,
# and distance large enough to hit the trainer without bouncing.
print(solution([5, 5], [0, 0], [4, 4], 10))  # Output should be 1

# Test case with your_position and trainer_position in opposite corners of a room,
# and distance large enough to hit the trainer with bouncing.
print(solution([5, 5], [0, 0], [4, 4], 15))  # Output should be 1

# Test case with your_position and trainer_position in opposite corners of a room,
# and distance that doesn't hit the trainer.
print(solution([5, 5], [0, 0], [4, 4], 9))  # Output should be 0

# Test case with maximum room dimensions and maximum distance.
print(solution([1250, 1250], [0, 0], [1249, 1249], 10000))  # Output should be 2

# Test case with maximum room dimensions, maximum distance, and both positions at the center of the room.
print(solution([1250, 1250], [625, 625], [625, 625], 10000))  # Output should be 1

# Test case with maximum room dimensions, maximum distance, and both positions on the same axis.
print(solution([1250, 1250], [0, 625], [0, 1249], 10000))  # Output should be 1

# Test case with maximum room dimensions, maximum distance, and both positions on the opposite corners of the room.
print(solution([1250, 1250], [0, 0], [1249, 1249], 1))  # Output should be 0

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    if getDistance(your_position, trainer_position) > distance:
        return 0


def solution(dimensions, your_position, trainer_position, distance):
    def getDistance(position1, position2):
        if getDistance(your_position, trainer_position) > distance:
            return 0
        else:
            return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

    def getRootBearing(start, end):
        return math.atan2(end[1] - start[1], end[0] - start[0])

    def findMaxRoom(dimension, distance, your_position):
        a, b = your_position
        x, y = dimension
        roomsAboveX = (distance + b) // y + 1
        roomsRightY = (distance + a) // x + 1
        return max(roomsRightY, roomsAboveX)

    def getPosition(dimension, trainer_position, n):
        res = []
        a, b = trainer_position
        x, y = dimension
        if n % 2 == 0:
            res.extend([(-a - n * x, (n + 2) * y - b), ((n + 2) * x - a, (n + 2) * y - b), (-a - n * x, -b - n * y), ((n + 2) * x - a, -b - n * y), ((-a - n * x), b), (a, (n + 2) * y - b), ((n + 2) * x - a, b), (a, -b - n * y)])
        else:
            res.extend(
                [(a - (n + 1) * x, (n + 1) * y + b), ((n + 1) * x + a, (n + 1) * y + b), (a - (n + 1) * x, b - (n + 1) * y), ((n + 1) * x + a, b - (n + 1) * y), (a - (n + 1) * x, b), (a, (n + 1) * y + b), ((n + 1) * x + a, b), (a, b - (n + 1) * y)])
        while n > 0:
            if n % 2 == 1:
                res.extend(
                    [(-a - (n - 1) * x, res[0][1]), (res[0][0], (n + 1) * y - b), ((n + 1) * x - a, res[1][1]), (res[1][0], (n + 1) * y - b), (res[2][0], -b - (n - 1) * y), (-a - (n - 1) * x, res[2][1]), ((n + 1) * x - a, res[3][1]), (res[3][0], -b - (n - 1) * y)])
            else:
                res.extend([(a - n * x, res[0][1]), (res[0][0], n * y + b), (n * x + a, res[1][1]), (res[1][0], n * y + b), (res[2][0], b - n * y), (a - n * x, res[2][1]), (n * x + a, res[3][1]), (res[3][0], b - n * y)])
            n -= 1
        return res

    def checkPoint(your_position, position, dimension):
        x, y = dimension
        a1, b1 = position
        leftUp = getRootBearing(your_position, [0, y])
        rightDown = getRootBearing(your_position, [x, 0])
        leftDown = getRootBearing(your_position, [0, 0])
        rightUp = getRootBearing(your_position, [x, y])
        if position[0] != your_position[0] and position[1] != your_position[1]:
            if a1 < 0 and b1 > 0 and getRootBearing(your_position, position) != leftUp:
                return True
            elif a1 > 0 and b1 > 0 and getRootBearing(your_position, position) != rightUp:
                return True
            elif a1 < 0 and b1 < 0 and getRootBearing(your_position, position) != leftDown:
                return True
            elif a1 > 0 and b1 < 0 and getRootBearing(your_position, position) != rightDown:
                return True
            else:
                return False
        else:
            return False

    if getDistance(your_position, trainer_position) > distance:
        return 0

    res = {getRootBearing(your_position, trainer_position): getDistance(your_position, trainer_position)}
    maxRoom = findMaxRoom(dimensions, distance, your_position)
    unique_directions = set()

    # check if the position is in the same direction as your_position mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, your_position, num):
            if checkPoint(your_position, position, dimensions) and getDistance(your_position, position) < distance and getRootBearing(your_position, position) not in unique_directions:
                unique_directions.add(getRootBearing(your_position, position))

    # check every position of mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, trainer_position, num):
            if checkPoint(your_position, position, dimensions) and getRootBearing(your_position, position) not in res and getDistance(your_position, position) <= distance and getRootBearing(your_position, position) not in unique_directions:
                res[getRootBearing(your_position, position)] = getDistance(your_position, position)
            elif getRootBearing(your_position, position) in unique_directions:
                if unique_directions[getRootBearing(your_position, position)] > getDistance(your_position, position):
                    res[getRootBearing(your_position, position)] = getDistance(your_position, position)

    return len(res)

# Test case with a small room, your_position and trainer_position on the same axis,
# and distance that doesn't hit the trainer.
print(solution([2, 2], [0, 1], [0, 0], 1))  # Output should be 0

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    if getDistance(your_position, trainer_position) > distance:
        return 0


def solution(dimensions, your_position, trainer_position, distance):
    def getDistance(position1, position2):
        if getDistance(your_position, trainer_position) > distance:
            return 0
        else:
            return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

    def getRootBearing(start, end):
        return math.atan2(end[1] - start[1], end[0] - start[0])

    def findMaxRoom(dimension, distance, your_position):
        a, b = your_position
        x, y = dimension
        roomsAboveX = (distance + b) // y + 1
        roomsRightY = (distance + a) // x + 1
        return max(roomsRightY, roomsAboveX)

    def getPosition(dimension, trainer_position, n):
        res = []
        a, b = trainer_position
        x, y = dimension
        if n % 2 == 0:
            res.extend([(-a - n * x, (n + 2) * y - b), ((n + 2) * x - a, (n + 2) * y - b), (-a - n * x, -b - n * y), ((n + 2) * x - a, -b - n * y), ((-a - n * x), b), (a, (n + 2) * y - b), ((n + 2) * x - a, b), (a, -b - n * y)])
        else:
            res.extend(
                [(a - (n + 1) * x, (n + 1) * y + b), ((n + 1) * x + a, (n + 1) * y + b), (a - (n + 1) * x, b - (n + 1) * y), ((n + 1) * x + a, b - (n + 1) * y), (a - (n + 1) * x, b), (a, (n + 1) * y + b), ((n + 1) * x + a, b), (a, b - (n + 1) * y)])
        while n > 0:
            if n % 2 == 1:
                res.extend(
                    [(-a - (n - 1) * x, res[0][1]), (res[0][0], (n + 1) * y - b), ((n + 1) * x - a, res[1][1]), (res[1][0], (n + 1) * y - b), (res[2][0], -b - (n - 1) * y), (-a - (n - 1) * x, res[2][1]), ((n + 1) * x - a, res[3][1]), (res[3][0], -b - (n - 1) * y)])
            else:
                res.extend([(a - n * x, res[0][1]), (res[0][0], n * y + b), (n * x + a, res[1][1]), (res[1][0], n * y + b), (res[2][0], b - n * y), (a - n * x, res[2][1]), (n * x + a, res[3][1]), (res[3][0], b - n * y)])
            n -= 1
        return res

    def checkPoint(your_position, position, dimension):
        x, y = dimension
        a1, b1 = position
        leftUp = getRootBearing(your_position, [0, y])
        rightDown = getRootBearing(your_position, [x, 0])
        leftDown = getRootBearing(your_position, [0, 0])
        rightUp = getRootBearing(your_position, [x, y])
        if position[0] != your_position[0] and position[1] != your_position[1]:
            if a1 < 0 and b1 > 0 and getRootBearing(your_position, position) != leftUp:
                return True
            elif a1 > 0 and b1 > 0 and getRootBearing(your_position, position) != rightUp:
                return True
            elif a1 < 0 and b1 < 0 and getRootBearing(your_position, position) != leftDown:
                return True
            elif a1 > 0 and b1 < 0 and getRootBearing(your_position, position) != rightDown:
                return True
            else:
                return False
        else:
            return False

    if getDistance(your_position, trainer_position) > distance:
        return 0

    res = {getRootBearing(your_position, trainer_position): getDistance(your_position, trainer_position)}
    maxRoom = findMaxRoom(dimensions, distance, your_position)
    unique_directions = set()

    # check if the position is in the same direction as your_position mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, your_position, num):
            if checkPoint(your_position, position, dimensions) and getDistance(your_position, position) < distance and getRootBearing(your_position, position) not in unique_directions:
                unique_directions.add(getRootBearing(your_position, position))

    # check every position of mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, trainer_position, num):
            if checkPoint(your_position, position, dimensions) and getRootBearing(your_position, position) not in res and getDistance(your_position, position) <= distance and getRootBearing(your_position, position) not in unique_directions:
                res[getRootBearing(your_position, position)] = getDistance(your_position, position)
            elif getRootBearing(your_position, position) in unique_directions:
                if unique_directions[getRootBearing(your_position, position)] > getDistance(your_position, position):
                    res[getRootBearing(your_position, position)] = getDistance(your_position, position)

    return len(res)

# Test case with a small room, your_position and trainer_position on the same axis,
# and distance that doesn't hit the trainer.
print(solution([2, 2], [0, 1], [0, 0], 1))  # Output should be 0

# %%
import math

def solution(dimensions, your_position, trainer_position, distance):
    def getDistance(position1, position2):
        return math.sqrt((position1[0] - position2[0]) ** 2 + (position1[1] - position2[1]) ** 2)

    def getRootBearing(start, end):
        return math.atan2(end[1] - start[1], end[0] - start[0])

    def findMaxRoom(dimension, distance, your_position):
        a, b = your_position
        x, y = dimension
        roomsAboveX = (distance + b) // y + 1
        roomsRightY = (distance + a) // x + 1
        return max(roomsRightY, roomsAboveX)

    def getPosition(dimension, trainer_position, n):
        res = []
        a, b = trainer_position
        x, y = dimension
        if n % 2 == 0:
            res.extend([(-a - n * x, (n + 2) * y - b), ((n + 2) * x - a, (n + 2) * y - b), (-a - n * x, -b - n * y), ((n + 2) * x - a, -b - n * y), ((-a - n * x), b), (a, (n + 2) * y - b), ((n + 2) * x - a, b), (a, -b - n * y)])
        else:
            res.extend(
                [(a - (n + 1) * x, (n + 1) * y + b), ((n + 1) * x + a, (n + 1) * y + b), (a - (n + 1) * x, b - (n + 1) * y), ((n + 1) * x + a, b - (n + 1) * y), (a - (n + 1) * x, b), (a, (n + 1) * y + b), ((n + 1) * x + a, b), (a, b - (n + 1) * y)])
        while n > 0:
            if n % 2 == 1:
                res.extend(
                    [(-a - (n - 1) * x, res[0][1]), (res[0][0], (n + 1) * y - b), ((n + 1) * x - a, res[1][1]), (res[1][0], (n + 1) * y - b), (res[2][0], -b - (n - 1) * y), (-a - (n - 1) * x, res[2][1]), ((n + 1) * x - a, res[3][1]), (res[3][0], -b - (n - 1) * y)])
            else:
                res.extend([(a - n * x, res[0][1]), (res[0][0], n * y + b), (n * x + a, res[1][1]), (res[1][0], n * y + b), (res[2][0], b - n * y), (a - n * x, res[2][1]), (n * x + a, res[3][1]), (res[3][0], b - n * y)])
            n -= 1
        return res

    def checkPoint(your_position, position, dimension):
        x, y = dimension
        a1, b1 = position
        leftUp = getRootBearing(your_position, [0, y])
        rightDown = getRootBearing(your_position, [x, 0])
        leftDown = getRootBearing(your_position, [0, 0])
        rightUp = getRootBearing(your_position, [x, y])
        if position[0] != your_position[0] and position[1] != your_position[1]:
            if a1 < 0 and b1 > 0 and getRootBearing(your_position, position) != leftUp:
                return True
            elif a1 > 0 and b1 > 0 and getRootBearing(your_position, position) != rightUp:
                return True
            elif a1 < 0 and b1 < 0 and getRootBearing(your_position, position) != leftDown:
                return True
            elif a1 > 0 and b1 < 0 and getRootBearing(your_position, position) != rightDown:
                return True
            else:
                return False
        else:
            return False

    if getDistance(your_position, trainer_position) > distance:
        return 0

    res = {getRootBearing(your_position, trainer_position): getDistance(your_position, trainer_position)}
    maxRoom = findMaxRoom(dimensions, distance, your_position)
    unique_directions = set()

    # check if the position is in the same direction as your_position mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, your_position, num):
            if checkPoint(your_position, position, dimensions) and getDistance(your_position, position) < distance and getRootBearing(your_position, position) not in unique_directions:
                unique_directions.add(getRootBearing(your_position, position))

    # check every position of mirroring
    for num in range(maxRoom):
        for position in getPosition(dimensions, trainer_position, num):
            if checkPoint(your_position, position, dimensions) and getRootBearing(your_position, position) not in res and getDistance(your_position, position) <= distance and getRootBearing(your_position, position) not in unique_directions:
                res[getRootBearing(your_position, position)] = getDistance(your_position, position)
            elif getRootBearing(your_position, position) in unique_directions:
                if unique_directions[getRootBearing(your_position, position)] > getDistance(your_position, position):
                    res[getRootBearing(your_position, position)] = getDistance(your_position, position)

    return len(res)

# Test case with a small room, your_position and trainer_position on the same axis,
# and distance that doesn't hit the trainer.
print(solution([2, 2], [0, 1], [0, 0], 1))  # Output should be 0
# Out:
# 1
